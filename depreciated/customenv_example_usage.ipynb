# %%
from customenv import CustomDoorKey

from minigrid.wrappers import ImgObsWrapper
from stable_baselines3 import PPO

from customfeatureextractor import CNNFeaturesExtractor, CustomFeatureExtractor, CustomImgObsWrapper

from callback import CustomRewardCallback
from plot import make_plot

import matplotlib.pyplot as plt

# size is grid size
# intermediate reward determines if picking up key/opening door gives reward
# randomimze goal determines if goal should be randomized (cell on last column)
env = CustomDoorKey(size=12, intermediate_reward=True, randomize_goal=True, render_mode = "rgb")
default_env = ImgObsWrapper(env)
custom_env = CustomImgObsWrapper(env)
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
policy_kwargs = dict(
    features_extractor_class=CNNFeaturesExtractor,
    features_extractor_kwargs=dict(features_dim=128, regularization = False),
)

custom_policy_kwargs = dict(
    features_extractor_class=CustomFeatureExtractor,
    features_extractor_kwargs=dict(cnn_features_dim=128, mlp_features_dim=32, regularization = True),
)

max_reward = 0.9
callback = CustomRewardCallback(check_freq=1000, reward_threshold=max_reward)  # set callback

# %%
# custom behavior, Babak can temper with this
model = PPO("MultiInputPolicy", custom_env, policy_kwargs=custom_policy_kwargs)
model.learn(3e5, callback = callback)

model.save("model_12x12_all")
plt.savefig('12x12_all.png')
# Out:
# Threshold reached in 655.38 seconds and 181154 steps.
# Stopping training as the mean reward 0.9022225141525269 is above the threshold 0.9

# %%
model = PPO("CnnPolicy", default_env, policy_kwargs=policy_kwargs, verbose=1)
model.learn(2e5, callback = callback)

model.save("model_8x8")
plt.savefig('8x8.png')
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 0.0773   |
# | time/              |          |
# |    fps             | 616      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 0.069        |
# | time/                   |              |
# |    fps                  | 530          |
# |    iterations           | 2            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0109270215 |
# |    clip_fraction        | 0.0795       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.588       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00062      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00641     |
# |    value_loss           | 7.48e-05     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 0.0685     |
# | time/                   |            |
# |    fps                  | 489        |
# |    iterations           | 3          |
# |    time_elapsed         | 12         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01308268 |
# |    clip_fraction        | 0.0465     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.92      |
# |    explained_variance   | -0.3       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00558   |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.00388   |
# |    value_loss           | 2.63e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 0.0821      |
# | time/                   |             |
# |    fps                  | 454         |
# |    iterations           | 4           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013422502 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.91       |
# |    explained_variance   | -0.0627     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00855     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00746    |
# |    value_loss           | 5.61e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 954          |
# |    ep_rew_mean          | 0.181        |
# | time/                   |              |
# |    fps                  | 435          |
# |    iterations           | 5            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0088293655 |
# |    clip_fraction        | 0.0611       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.92        |
# |    explained_variance   | -0.0197      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0115       |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0045      |
# |    value_loss           | 0.00125      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 961          |
# |    ep_rew_mean          | 0.163        |
# | time/                   |              |
# |    fps                  | 435          |
# |    iterations           | 6            |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0065865703 |
# |    clip_fraction        | 0.0353       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | -0.000157    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00995      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00305     |
# |    value_loss           | 0.00109      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 967         |
# |    ep_rew_mean          | 0.152       |
# | time/                   |             |
# |    fps                  | 434         |
# |    iterations           | 7           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.011429902 |
# |    clip_fraction        | 0.0494      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | -0.172      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0132     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00589    |
# |    value_loss           | 9.6e-05     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 971         |
# |    ep_rew_mean          | 0.143       |
# | time/                   |             |
# |    fps                  | 425         |
# |    iterations           | 8           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.013008382 |
# |    clip_fraction        | 0.0602      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.92       |
# |    explained_variance   | -0.84       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00762    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00473    |
# |    value_loss           | 8.45e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 974         |
# |    ep_rew_mean          | 0.133       |
# | time/                   |             |
# |    fps                  | 417         |
# |    iterations           | 9           |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.011680733 |
# |    clip_fraction        | 0.0894      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.91       |
# |    explained_variance   | -1.16       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.027      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00654    |
# |    value_loss           | 5.68e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 959          |
# |    ep_rew_mean          | 0.17         |
# | time/                   |              |
# |    fps                  | 411          |
# |    iterations           | 10           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0071940618 |
# |    clip_fraction        | 0.0782       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.9         |
# |    explained_variance   | 0.0153       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00367      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00549     |
# |    value_loss           | 8.8e-05      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 927        |
# |    ep_rew_mean          | 0.241      |
# | time/                   |            |
# |    fps                  | 413        |
# |    iterations           | 11         |
# |    time_elapsed         | 54         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.01591818 |
# |    clip_fraction        | 0.135      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.86      |
# |    explained_variance   | 0.0215     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.035     |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.00639   |
# |    value_loss           | 0.00307    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 933          |
# |    ep_rew_mean          | 0.23         |
# | time/                   |              |
# |    fps                  | 415          |
# |    iterations           | 12           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0123198945 |
# |    clip_fraction        | 0.112        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.85        |
# |    explained_variance   | -0.0331      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00203      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00696     |
# |    value_loss           | 0.0034       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 938         |
# |    ep_rew_mean          | 0.237       |
# | time/                   |             |
# |    fps                  | 411         |
# |    iterations           | 13          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.023346277 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | -1.9        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00615    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0159     |
# |    value_loss           | 0.000182    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 941         |
# |    ep_rew_mean          | 0.255       |
# | time/                   |             |
# |    fps                  | 406         |
# |    iterations           | 14          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.009073909 |
# |    clip_fraction        | 0.0955      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | -0.056      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0184     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00403    |
# |    value_loss           | 0.00103     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 928         |
# |    ep_rew_mean          | 0.276       |
# | time/                   |             |
# |    fps                  | 401         |
# |    iterations           | 15          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.010339525 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.76       |
# |    explained_variance   | -0.0681     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0164     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00692    |
# |    value_loss           | 0.00127     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 876          |
# |    ep_rew_mean          | 0.356        |
# | time/                   |              |
# |    fps                  | 396          |
# |    iterations           | 16           |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0128998635 |
# |    clip_fraction        | 0.146        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.78        |
# |    explained_variance   | 0.00469      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0203      |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.0095      |
# |    value_loss           | 0.00134      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 883         |
# |    ep_rew_mean          | 0.344       |
# | time/                   |             |
# |    fps                  | 393         |
# |    iterations           | 17          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.012475153 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.74       |
# |    explained_variance   | 0.00383     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0239     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00994    |
# |    value_loss           | 0.00793     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 888         |
# |    ep_rew_mean          | 0.337       |
# | time/                   |             |
# |    fps                  | 389         |
# |    iterations           | 18          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.025076542 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.79       |
# |    explained_variance   | -1.37       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0706     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0192     |
# |    value_loss           | 0.000666    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 893         |
# |    ep_rew_mean          | 0.325       |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 19          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.012471436 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.79       |
# |    explained_variance   | -0.111      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0101     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 0.000371    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 898        |
# |    ep_rew_mean          | 0.315      |
# | time/                   |            |
# |    fps                  | 384        |
# |    iterations           | 20         |
# |    time_elapsed         | 106        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.01074152 |
# |    clip_fraction        | 0.124      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.8       |
# |    explained_variance   | -0.932     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0151    |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.00855   |
# |    value_loss           | 0.000126   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 896         |
# |    ep_rew_mean          | 0.32        |
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 21          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.010616427 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.79       |
# |    explained_variance   | -0.417      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00214    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00889    |
# |    value_loss           | 9.14e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 900          |
# |    ep_rew_mean          | 0.311        |
# | time/                   |              |
# |    fps                  | 379          |
# |    iterations           | 22           |
# |    time_elapsed         | 118          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0069176434 |
# |    clip_fraction        | 0.101        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.71        |
# |    explained_variance   | 0.0106       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0218      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00423     |
# |    value_loss           | 0.0013       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 904         |
# |    ep_rew_mean          | 0.318       |
# | time/                   |             |
# |    fps                  | 377         |
# |    iterations           | 23          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.016711816 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | -0.754      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0376     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.012      |
# |    value_loss           | 0.000217    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 907          |
# |    ep_rew_mean          | 0.313        |
# | time/                   |              |
# |    fps                  | 376          |
# |    iterations           | 24           |
# |    time_elapsed         | 130          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0148872975 |
# |    clip_fraction        | 0.191        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.65        |
# |    explained_variance   | -0.0577      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0201      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00896     |
# |    value_loss           | 0.00162      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 911         |
# |    ep_rew_mean          | 0.305       |
# | time/                   |             |
# |    fps                  | 374         |
# |    iterations           | 25          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.014930314 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.64       |
# |    explained_variance   | -0.696      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0227     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 0.00024     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 901         |
# |    ep_rew_mean          | 0.325       |
# | time/                   |             |
# |    fps                  | 372         |
# |    iterations           | 26          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.011492629 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | -0.741      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0411     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 9.38e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 904         |
# |    ep_rew_mean          | 0.316       |
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 27          |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.016045492 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.61       |
# |    explained_variance   | 0.0342      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0115     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00813    |
# |    value_loss           | 0.00469     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 907         |
# |    ep_rew_mean          | 0.317       |
# | time/                   |             |
# |    fps                  | 369         |
# |    iterations           | 28          |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.028471734 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | -3.49       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.039      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0141     |
# |    value_loss           | 0.000174    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 903         |
# |    ep_rew_mean          | 0.33        |
# | time/                   |             |
# |    fps                  | 367         |
# |    iterations           | 29          |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.008099603 |
# |    clip_fraction        | 0.0963      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | -0.0618     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00825    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00739    |
# |    value_loss           | 0.00074     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 901         |
# |    ep_rew_mean          | 0.33        |
# | time/                   |             |
# |    fps                  | 366         |
# |    iterations           | 30          |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.011676394 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | 0.0185      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0137     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00608    |
# |    value_loss           | 0.0021      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 889         |
# |    ep_rew_mean          | 0.352       |
# | time/                   |             |
# |    fps                  | 364         |
# |    iterations           | 31          |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.014964505 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | -0.11       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00278    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0142     |
# |    value_loss           | 0.00137     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 881          |
# |    ep_rew_mean          | 0.367        |
# | time/                   |              |
# |    fps                  | 363          |
# |    iterations           | 32           |
# |    time_elapsed         | 180          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0124739045 |
# |    clip_fraction        | 0.146        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.65        |
# |    explained_variance   | 0.0606       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00518     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.0135      |
# |    value_loss           | 0.00451      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 884         |
# |    ep_rew_mean          | 0.359       |
# | time/                   |             |
# |    fps                  | 362         |
# |    iterations           | 33          |
# |    time_elapsed         | 186         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.015818756 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | -0.124      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0123     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 0.00333     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 887         |
# |    ep_rew_mean          | 0.357       |
# | time/                   |             |
# |    fps                  | 362         |
# |    iterations           | 34          |
# |    time_elapsed         | 192         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.018945176 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.57       |
# |    explained_variance   | -1.53       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0318     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 0.000151    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 890         |
# |    ep_rew_mean          | 0.358       |
# | time/                   |             |
# |    fps                  | 361         |
# |    iterations           | 35          |
# |    time_elapsed         | 198         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.015905507 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.57       |
# |    explained_variance   | 0.000571    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00512    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00851    |
# |    value_loss           | 0.00085     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 893         |
# |    ep_rew_mean          | 0.357       |
# | time/                   |             |
# |    fps                  | 361         |
# |    iterations           | 36          |
# |    time_elapsed         | 204         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.011187765 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.54       |
# |    explained_variance   | 0.0283      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0108     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0056     |
# |    value_loss           | 0.00131     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 889         |
# |    ep_rew_mean          | 0.359       |
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 37          |
# |    time_elapsed         | 210         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.009891209 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.5        |
# |    explained_variance   | -0.0339     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00559    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00638    |
# |    value_loss           | 0.000975    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 876         |
# |    ep_rew_mean          | 0.38        |
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 38          |
# |    time_elapsed         | 216         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.012718663 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | -0.0226     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0245     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00497    |
# |    value_loss           | 0.0029      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 879         |
# |    ep_rew_mean          | 0.379       |
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 39          |
# |    time_elapsed         | 222         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.012445768 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.0113      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0179     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00612    |
# |    value_loss           | 0.00756     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 881          |
# |    ep_rew_mean          | 0.372        |
# | time/                   |              |
# |    fps                  | 358          |
# |    iterations           | 40           |
# |    time_elapsed         | 228          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0146501325 |
# |    clip_fraction        | 0.191        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.0462      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0288      |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.0109      |
# |    value_loss           | 0.00111      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 884         |
# |    ep_rew_mean          | 0.365       |
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 41          |
# |    time_elapsed         | 234         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.021263853 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -1.32       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0205     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 0.000107    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 886        |
# |    ep_rew_mean          | 0.361      |
# | time/                   |            |
# |    fps                  | 358        |
# |    iterations           | 42         |
# |    time_elapsed         | 239        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.01302601 |
# |    clip_fraction        | 0.137      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.46      |
# |    explained_variance   | -0.225     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0235    |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.00682   |
# |    value_loss           | 0.000126   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 889         |
# |    ep_rew_mean          | 0.36        |
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 43          |
# |    time_elapsed         | 245         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.013079329 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -1.22       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0443      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00858    |
# |    value_loss           | 0.00023     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 891         |
# |    ep_rew_mean          | 0.357       |
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 44          |
# |    time_elapsed         | 250         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.013714712 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.0501      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0276     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00821    |
# |    value_loss           | 0.000984    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 891        |
# |    ep_rew_mean          | 0.36       |
# | time/                   |            |
# |    fps                  | 361        |
# |    iterations           | 45         |
# |    time_elapsed         | 255        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.03658258 |
# |    clip_fraction        | 0.225      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.37      |
# |    explained_variance   | -0.873     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00391    |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.0159    |
# |    value_loss           | 0.000124   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 882         |
# |    ep_rew_mean          | 0.374       |
# | time/                   |             |
# |    fps                  | 362         |
# |    iterations           | 46          |
# |    time_elapsed         | 259         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.012788006 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | -0.143      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0078     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00493    |
# |    value_loss           | 0.00031     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 882       |
# |    ep_rew_mean          | 0.379     |
# | time/                   |           |
# |    fps                  | 363       |
# |    iterations           | 47        |
# |    time_elapsed         | 264       |
# |    total_timesteps      | 96256     |
# | train/                  |           |
# |    approx_kl            | 0.0177072 |
# |    clip_fraction        | 0.212     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.18     |
# |    explained_variance   | 0.0519    |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0278   |
# |    n_updates            | 460       |
# |    policy_gradient_loss | -0.00901  |
# |    value_loss           | 0.00377   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 878         |
# |    ep_rew_mean          | 0.386       |
# | time/                   |             |
# |    fps                  | 364         |
# |    iterations           | 48          |
# |    time_elapsed         | 269         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.017332807 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | -0.178      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0155     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00934    |
# |    value_loss           | 0.00145     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 860         |
# |    ep_rew_mean          | 0.416       |
# | time/                   |             |
# |    fps                  | 364         |
# |    iterations           | 49          |
# |    time_elapsed         | 275         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.009877556 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.0618      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00433    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00389    |
# |    value_loss           | 0.0047      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 860          |
# |    ep_rew_mean          | 0.419        |
# | time/                   |              |
# |    fps                  | 364          |
# |    iterations           | 50           |
# |    time_elapsed         | 280          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0071622375 |
# |    clip_fraction        | 0.0713       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.0792       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000485     |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00465     |
# |    value_loss           | 0.0064       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 851         |
# |    ep_rew_mean          | 0.439       |
# | time/                   |             |
# |    fps                  | 364         |
# |    iterations           | 51          |
# |    time_elapsed         | 286         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.009099992 |
# |    clip_fraction        | 0.0603      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.993      |
# |    explained_variance   | -0.401      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0381     |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00745    |
# |    value_loss           | 0.000608    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 840         |
# |    ep_rew_mean          | 0.45        |
# | time/                   |             |
# |    fps                  | 364         |
# |    iterations           | 52          |
# |    time_elapsed         | 291         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.017561955 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -0.29       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0335     |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 0.00507     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 840        |
# |    ep_rew_mean          | 0.457      |
# | time/                   |            |
# |    fps                  | 366        |
# |    iterations           | 53         |
# |    time_elapsed         | 296        |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.00854777 |
# |    clip_fraction        | 0.102      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.14      |
# |    explained_variance   | -0.0412    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.039      |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.0033    |
# |    value_loss           | 0.00849    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 833         |
# |    ep_rew_mean          | 0.468       |
# | time/                   |             |
# |    fps                  | 366         |
# |    iterations           | 54          |
# |    time_elapsed         | 301         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.012489394 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.037       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00325    |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00769    |
# |    value_loss           | 0.00191     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 822         |
# |    ep_rew_mean          | 0.484       |
# | time/                   |             |
# |    fps                  | 367         |
# |    iterations           | 55          |
# |    time_elapsed         | 306         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.007271736 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.0603      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -5.32e-05   |
# ...
# |    policy_gradient_loss | -0.00491    |
# |    value_loss           | 0.00379     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 721         |
# |    ep_rew_mean          | 0.616       |
# | time/                   |             |
# |    fps                  | 383         |
# |    iterations           | 81          |
# |    time_elapsed         | 432         |
# |    total_timesteps      | 165888      |
# | train/                  |             |
# |    approx_kl            | 0.025292862 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.121       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0061     |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 0.00315     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 723        |
# |    ep_rew_mean          | 0.623      |
# | time/                   |            |
# |    fps                  | 383        |
# |    iterations           | 82         |
# |    time_elapsed         | 437        |
# |    total_timesteps      | 167936     |
# | train/                  |            |
# |    approx_kl            | 0.01464669 |
# |    clip_fraction        | 0.156      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.11      |
# |    explained_variance   | 0.00367    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.014     |
# |    n_updates            | 810        |
# |    policy_gradient_loss | -0.0108    |
# |    value_loss           | 0.00369    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 703        |
# |    ep_rew_mean          | 0.644      |
# | time/                   |            |
# |    fps                  | 384        |
# |    iterations           | 83         |
# |    time_elapsed         | 442        |
# |    total_timesteps      | 169984     |
# | train/                  |            |
# |    approx_kl            | 0.01803722 |
# |    clip_fraction        | 0.114      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.1       |
# |    explained_variance   | 0.064      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0174    |
# |    n_updates            | 820        |
# |    policy_gradient_loss | -0.00938   |
# |    value_loss           | 0.00214    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 712         |
# |    ep_rew_mean          | 0.636       |
# | time/                   |             |
# |    fps                  | 384         |
# |    iterations           | 84          |
# |    time_elapsed         | 447         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.013148603 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.996      |
# |    explained_variance   | 0.191       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0139      |
# |    n_updates            | 830         |
# |    policy_gradient_loss | -0.00861    |
# |    value_loss           | 0.0138      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 712         |
# |    ep_rew_mean          | 0.641       |
# | time/                   |             |
# |    fps                  | 385         |
# |    iterations           | 85          |
# |    time_elapsed         | 451         |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.022389345 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.648      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0405     |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.017      |
# |    value_loss           | 0.00383     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 721         |
# |    ep_rew_mean          | 0.632       |
# | time/                   |             |
# |    fps                  | 385         |
# |    iterations           | 86          |
# |    time_elapsed         | 456         |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.020710805 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.935      |
# |    explained_variance   | 0.562       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00799    |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.00731    |
# |    value_loss           | 0.00373     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 728         |
# |    ep_rew_mean          | 0.618       |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 87          |
# |    time_elapsed         | 460         |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.012784993 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.917      |
# |    explained_variance   | 0.748       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0252     |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.00726    |
# |    value_loss           | 0.00195     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 727         |
# |    ep_rew_mean          | 0.619       |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 88          |
# |    time_elapsed         | 465         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.010345969 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.849      |
# |    explained_variance   | -0.174      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00951    |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.00751    |
# |    value_loss           | 0.00095     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 723         |
# |    ep_rew_mean          | 0.621       |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 89          |
# |    time_elapsed         | 470         |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.018569544 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.893      |
# |    explained_variance   | 0.0906      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0134     |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.00888    |
# |    value_loss           | 0.00584     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 730         |
# |    ep_rew_mean          | 0.609       |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 90          |
# |    time_elapsed         | 475         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.011468205 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.908      |
# |    explained_variance   | 0.424       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0159     |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.00485    |
# |    value_loss           | 0.00192     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 713         |
# |    ep_rew_mean          | 0.629       |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 91          |
# |    time_elapsed         | 480         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.019482687 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.814      |
# |    explained_variance   | 0.121       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0345     |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.00663    |
# |    value_loss           | 0.00194     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 708         |
# |    ep_rew_mean          | 0.64        |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 92          |
# |    time_elapsed         | 485         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.018051546 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.79       |
# |    explained_variance   | 0.199       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00672     |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.00581    |
# |    value_loss           | 0.00713     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 699         |
# |    ep_rew_mean          | 0.656       |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 93          |
# |    time_elapsed         | 490         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.007790547 |
# |    clip_fraction        | 0.0752      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.718      |
# |    explained_variance   | -0.148      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0102     |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.00335    |
# |    value_loss           | 0.0047      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 699         |
# |    ep_rew_mean          | 0.658       |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 94          |
# |    time_elapsed         | 495         |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.009826993 |
# |    clip_fraction        | 0.0696      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.598      |
# |    explained_variance   | 0.283       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00994     |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.00528    |
# |    value_loss           | 0.0072      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 699         |
# |    ep_rew_mean          | 0.659       |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 95          |
# |    time_elapsed         | 500         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.014018737 |
# |    clip_fraction        | 0.095       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.637      |
# |    explained_variance   | 0.121       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0318      |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.00757    |
# |    value_loss           | 0.00471     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 702         |
# |    ep_rew_mean          | 0.656       |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 96          |
# |    time_elapsed         | 505         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.029829584 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.847      |
# |    explained_variance   | -0.234      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0163     |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.0143     |
# |    value_loss           | 0.00216     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 700         |
# |    ep_rew_mean          | 0.667       |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 97          |
# |    time_elapsed         | 511         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.028200496 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.7        |
# |    explained_variance   | 0.321       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0184     |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 0.00288     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 708         |
# |    ep_rew_mean          | 0.662       |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 98          |
# |    time_elapsed         | 516         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.020008419 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.622      |
# |    explained_variance   | 0.209       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0599     |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 0.00219     |
# -----------------------------------------
