# %%
from customenv import CustomDoorKey

from minigrid.wrappers import ImgObsWrapper
from stable_baselines3 import PPO

from customfeatureextractor import CNNFeaturesExtractor, CustomFeatureExtractor, CustomImgObsWrapper

from callback import CustomRewardCallback
from plot import make_plot

import matplotlib.pyplot as plt

# size is grid size
# intermediate reward determines if picking up key/opening door gives reward
# randomimze goal determines if goal should be randomized (cell on last column)
env = CustomDoorKey(size=8, intermediate_reward=True, randomize_goal=True, render_mode = "rgb")
default_env = ImgObsWrapper(env)
custom_env = CustomImgObsWrapper(env)

# %%
policy_kwargs = dict(
    features_extractor_class=CNNFeaturesExtractor,
    features_extractor_kwargs=dict(features_dim=128, regularization = False),
)

custom_policy_kwargs = dict(
    features_extractor_class=CustomFeatureExtractor,
    features_extractor_kwargs=dict(cnn_features_dim=128, mlp_features_dim=32),
)

max_reward = 0.9
callback = CustomRewardCallback(check_freq=1000, reward_threshold=max_reward)  # set callback

# %%
# custom behavior, Babak can temper with this
model = PPO("MultiInputPolicy", custom_env, policy_kwargs=custom_policy_kwargs, verbose=1)
model.learn(2e5)

# %%
# default behavior, Baldur can use this
model = PPO("CnnPolicy", default_env, policy_kwargs=policy_kwargs, verbose=1)
model.learn(2e5, callback=callback)
model.save("model_8x8s")

# the plot function also saves the plot
plt.savefig('8x8s.png')
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 0.0496   |
# | time/              |          |
# |    fps             | 524      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 0.126       |
# | time/                   |             |
# |    fps                  | 437         |
# |    iterations           | 2           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.013294364 |
# |    clip_fraction        | 0.0692      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | -0.581      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0226      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00611    |
# |    value_loss           | 5.36e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 946         |
# |    ep_rew_mean          | 0.273       |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 3           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011902081 |
# |    clip_fraction        | 0.0561      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | -0.00476    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0282     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00646    |
# |    value_loss           | 0.00029     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 960          |
# |    ep_rew_mean          | 0.229        |
# | time/                   |              |
# |    fps                  | 380          |
# |    iterations           | 4            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0063326797 |
# |    clip_fraction        | 0.0597       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.00344     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.012       |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00468     |
# |    value_loss           | 0.0014       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 968         |
# |    ep_rew_mean          | 0.199       |
# | time/                   |             |
# |    fps                  | 364         |
# |    iterations           | 5           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.014013635 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.93       |
# |    explained_variance   | -0.587      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.037      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 0.000101    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 973         |
# |    ep_rew_mean          | 0.18        |
# | time/                   |             |
# |    fps                  | 349         |
# |    iterations           | 6           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008927762 |
# |    clip_fraction        | 0.0564      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.92       |
# |    explained_variance   | -0.504      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0292     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00796    |
# |    value_loss           | 0.000115    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 894         |
# |    ep_rew_mean          | 0.308       |
# | time/                   |             |
# |    fps                  | 341         |
# |    iterations           | 7           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.018722512 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.9        |
# |    explained_variance   | -0.643      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0314      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 7.39e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 909         |
# |    ep_rew_mean          | 0.293       |
# | time/                   |             |
# |    fps                  | 340         |
# |    iterations           | 8           |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009913893 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.86       |
# |    explained_variance   | 0.0135      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0111     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00949    |
# |    value_loss           | 0.00485     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 833         |
# |    ep_rew_mean          | 0.418       |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 9           |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.010184253 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.83       |
# |    explained_variance   | -0.567      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00371    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00757    |
# |    value_loss           | 0.000514    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 847       |
# |    ep_rew_mean          | 0.39      |
# | time/                   |           |
# |    fps                  | 335       |
# |    iterations           | 10        |
# |    time_elapsed         | 61        |
# |    total_timesteps      | 20480     |
# | train/                  |           |
# |    approx_kl            | 0.0119665 |
# |    clip_fraction        | 0.137     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.79     |
# |    explained_variance   | 0.0519    |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0119   |
# |    n_updates            | 90        |
# |    policy_gradient_loss | -0.0104   |
# |    value_loss           | 0.00698   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 831         |
# |    ep_rew_mean          | 0.412       |
# | time/                   |             |
# |    fps                  | 333         |
# |    iterations           | 11          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.014317694 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.73       |
# |    explained_variance   | -2.67       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0241     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0128     |
# |    value_loss           | 0.000418    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 810         |
# |    ep_rew_mean          | 0.446       |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 12          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.017170614 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.68       |
# |    explained_variance   | 0.0253      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00614    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 0.00449     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 784         |
# |    ep_rew_mean          | 0.481       |
# | time/                   |             |
# |    fps                  | 331         |
# |    iterations           | 13          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.017438974 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.62       |
# |    explained_variance   | 0.0467      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0387     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.011      |
# |    value_loss           | 0.0036      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 763         |
# |    ep_rew_mean          | 0.51        |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 14          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.010884041 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.57       |
# |    explained_variance   | -0.0999     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00864     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 0.00648     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 763         |
# |    ep_rew_mean          | 0.514       |
# | time/                   |             |
# |    fps                  | 339         |
# |    iterations           | 15          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.016550776 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.51       |
# |    explained_variance   | -0.209      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000878    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00895    |
# |    value_loss           | 0.00797     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 772         |
# |    ep_rew_mean          | 0.499       |
# | time/                   |             |
# |    fps                  | 345         |
# |    iterations           | 16          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.015165899 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.49       |
# |    explained_variance   | -0.755      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0129     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0126     |
# |    value_loss           | 0.000632    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 771         |
# |    ep_rew_mean          | 0.496       |
# | time/                   |             |
# |    fps                  | 350         |
# |    iterations           | 17          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.012954335 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.5        |
# |    explained_variance   | -0.701      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0391     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0163     |
# |    value_loss           | 0.000894    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 781         |
# |    ep_rew_mean          | 0.488       |
# | time/                   |             |
# |    fps                  | 355         |
# |    iterations           | 18          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.012910988 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | 0.0385      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0366      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00575    |
# |    value_loss           | 0.00357     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 790         |
# |    ep_rew_mean          | 0.48        |
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 19          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.026375517 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.57       |
# |    explained_variance   | -0.549      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00323    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 0.00101     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 798         |
# |    ep_rew_mean          | 0.471       |
# | time/                   |             |
# |    fps                  | 364         |
# |    iterations           | 20          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.023871021 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.134      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0246     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0139     |
# |    value_loss           | 0.000845    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 796        |
# |    ep_rew_mean          | 0.477      |
# | time/                   |            |
# |    fps                  | 369        |
# |    iterations           | 21         |
# |    time_elapsed         | 116        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.01239833 |
# |    clip_fraction        | 0.139      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.49      |
# |    explained_variance   | -0.176     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0368     |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0146    |
# |    value_loss           | 0.000503   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 804         |
# |    ep_rew_mean          | 0.469       |
# | time/                   |             |
# |    fps                  | 372         |
# |    iterations           | 22          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.011574479 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | 0.0273      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0132     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.012      |
# |    value_loss           | 0.00179     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 811         |
# |    ep_rew_mean          | 0.456       |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 23          |
# |    time_elapsed         | 125         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.011174094 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -1.3        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0153     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 0.0002      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 817         |
# |    ep_rew_mean          | 0.443       |
# | time/                   |             |
# |    fps                  | 379         |
# |    iterations           | 24          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.011243696 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | -0.716      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0291     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00985    |
# |    value_loss           | 0.000143    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 823         |
# |    ep_rew_mean          | 0.438       |
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 25          |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.013864813 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | -0.748      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00543    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.015      |
# |    value_loss           | 0.000106    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 828         |
# |    ep_rew_mean          | 0.427       |
# | time/                   |             |
# |    fps                  | 385         |
# |    iterations           | 26          |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.017236423 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | -0.048      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0347     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0073     |
# |    value_loss           | 0.00139     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 833        |
# |    ep_rew_mean          | 0.424      |
# | time/                   |            |
# |    fps                  | 387        |
# |    iterations           | 27         |
# |    time_elapsed         | 142        |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.01552329 |
# |    clip_fraction        | 0.117      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.26      |
# |    explained_variance   | -0.708     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0532     |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.00705   |
# |    value_loss           | 0.000108   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 838         |
# |    ep_rew_mean          | 0.422       |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 28          |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.014669977 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.0664      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000624    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00457    |
# |    value_loss           | 0.00204     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 841         |
# |    ep_rew_mean          | 0.421       |
# | time/                   |             |
# |    fps                  | 384         |
# |    iterations           | 29          |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.029531304 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.0248     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0345     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 0.000751    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 845         |
# |    ep_rew_mean          | 0.419       |
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 30          |
# |    time_elapsed         | 160         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.015510955 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | -0.000216   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0394     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00947    |
# |    value_loss           | 0.000252    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 849         |
# |    ep_rew_mean          | 0.41        |
# | time/                   |             |
# |    fps                  | 380         |
# |    iterations           | 31          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.020099048 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -0.00358    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0646      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00899    |
# |    value_loss           | 0.00108     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 853         |
# |    ep_rew_mean          | 0.411       |
# | time/                   |             |
# |    fps                  | 379         |
# |    iterations           | 32          |
# |    time_elapsed         | 172         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.011447592 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.0582      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0163     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00557    |
# |    value_loss           | 0.00067     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 847        |
# |    ep_rew_mean          | 0.418      |
# | time/                   |            |
# |    fps                  | 376        |
# |    iterations           | 33         |
# |    time_elapsed         | 179        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.01300065 |
# |    clip_fraction        | 0.179      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.28      |
# |    explained_variance   | 0.0266     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0504    |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0107    |
# |    value_loss           | 0.000568   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 849         |
# |    ep_rew_mean          | 0.417       |
# | time/                   |             |
# |    fps                  | 375         |
# |    iterations           | 34          |
# |    time_elapsed         | 185         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.011439793 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | -0.0241     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0203     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0081     |
# |    value_loss           | 0.00497     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 852        |
# |    ep_rew_mean          | 0.409      |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 35         |
# |    time_elapsed         | 191        |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.07014877 |
# |    clip_fraction        | 0.216      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.23      |
# |    explained_variance   | -2.23      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0893    |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.031     |
# |    value_loss           | 0.00311    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 846         |
# |    ep_rew_mean          | 0.417       |
# | time/                   |             |
# |    fps                  | 374         |
# |    iterations           | 36          |
# |    time_elapsed         | 197         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.007572695 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.289       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0238     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00616    |
# |    value_loss           | 0.000306    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 851         |
# |    ep_rew_mean          | 0.411       |
# | time/                   |             |
# |    fps                  | 372         |
# |    iterations           | 37          |
# |    time_elapsed         | 203         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.012141117 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.00854     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00748    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0098     |
# |    value_loss           | 0.0045      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 838         |
# |    ep_rew_mean          | 0.429       |
# | time/                   |             |
# |    fps                  | 371         |
# |    iterations           | 38          |
# |    time_elapsed         | 209         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.015657488 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | -0.704      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00409     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 0.000947    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 841         |
# |    ep_rew_mean          | 0.424       |
# | time/                   |             |
# |    fps                  | 372         |
# |    iterations           | 39          |
# |    time_elapsed         | 214         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.020314902 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.0459      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0113      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 0.00641     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 845         |
# |    ep_rew_mean          | 0.417       |
# | time/                   |             |
# |    fps                  | 372         |
# |    iterations           | 40          |
# |    time_elapsed         | 219         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.013998793 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | -0.227      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0178     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00959    |
# |    value_loss           | 0.000935    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 848        |
# |    ep_rew_mean          | 0.411      |
# | time/                   |            |
# |    fps                  | 372        |
# |    iterations           | 41         |
# |    time_elapsed         | 225        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.02003438 |
# |    clip_fraction        | 0.15       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.03      |
# |    explained_variance   | 0.611      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00119    |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.00895   |
# |    value_loss           | 0.000301   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 838         |
# |    ep_rew_mean          | 0.426       |
# | time/                   |             |
# |    fps                  | 372         |
# |    iterations           | 42          |
# |    time_elapsed         | 230         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.014490455 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.96       |
# |    explained_variance   | 0.238       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0172     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00531    |
# |    value_loss           | 0.000122    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 824         |
# |    ep_rew_mean          | 0.442       |
# | time/                   |             |
# |    fps                  | 371         |
# |    iterations           | 43          |
# |    time_elapsed         | 236         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.006988937 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.978      |
# |    explained_variance   | 0.0891      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00847    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00498    |
# |    value_loss           | 0.00432     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 824         |
# |    ep_rew_mean          | 0.442       |
# | time/                   |             |
# |    fps                  | 371         |
# |    iterations           | 44          |
# |    time_elapsed         | 242         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.014073392 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.921      |
# |    explained_variance   | 0.13        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.022       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00669    |
# |    value_loss           | 0.00978     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 814         |
# |    ep_rew_mean          | 0.459       |
# | time/                   |             |
# |    fps                  | 371         |
# |    iterations           | 45          |
# |    time_elapsed         | 248         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.018653994 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.977      |
# |    explained_variance   | -0.158      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00758    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00856    |
# |    value_loss           | 0.0014      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 814         |
# |    ep_rew_mean          | 0.462       |
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 46          |
# |    time_elapsed         | 253         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.010900265 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.0793      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0168     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 0.00672     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 818        |
# |    ep_rew_mean          | 0.452      |
# | time/                   |            |
# |    fps                  | 370        |
# |    iterations           | 47         |
# |    time_elapsed         | 259        |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.06426981 |
# |    clip_fraction        | 0.164      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.971     |
# |    explained_variance   | -0.902     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0684    |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.00911   |
# |    value_loss           | 0.000633   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 819         |
# |    ep_rew_mean          | 0.449       |
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 48          |
# |    time_elapsed         | 265         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.008439522 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.122       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0031      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00594    |
# |    value_loss           | 0.00412     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 828         |
# |    ep_rew_mean          | 0.432       |
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 49          |
# |    time_elapsed         | 271         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.011662616 |
# |    clip_fraction        | 0.0973      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.966      |
# |    explained_variance   | -1.64       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0441     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00788    |
# |    value_loss           | 0.00189     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 814          |
# |    ep_rew_mean          | 0.453        |
# | time/                   |              |
# |    fps                  | 369          |
# |    iterations           | 50           |
# |    time_elapsed         | 276          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0085630175 |
# |    clip_fraction        | 0.0739       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.784       |
# |    explained_variance   | 0.357        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00195      |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00612     |
# |    value_loss           | 0.00228      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 816         |
# |    ep_rew_mean          | 0.449       |
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 51          |
# |    time_elapsed         | 282         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.010404394 |
# |    clip_fraction        | 0.0888      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.648      |
# |    explained_variance   | 0.288       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00891    |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00428    |
# |    value_loss           | 0.00502     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 830         |
# |    ep_rew_mean          | 0.426       |
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 52          |
# |    time_elapsed         | 287         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.037434205 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.871      |
# |    explained_variance   | -0.398      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0252     |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00838    |
# |    value_loss           | 0.000288    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 821         |
# |    ep_rew_mean          | 0.439       |
# | time/                   |             |
# |    fps                  | 369         |
# |    iterations           | 53          |
# |    time_elapsed         | 293         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.026304824 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.721      |
# |    explained_variance   | 0.551       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0288     |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 0.000258    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 830         |
# |    ep_rew_mean          | 0.427       |
# | time/                   |             |
# |    fps                  | 367         |
# |    iterations           | 54          |
# |    time_elapsed         | 300         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.024757383 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.769      |
# |    explained_variance   | 0.13        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0175     |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 0.00584     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 847         |
# |    ep_rew_mean          | 0.401       |
# | time/                   |             |
# |    fps                  | 366         |
# |    iterations           | 55          |
# |    time_elapsed         | 307         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.026908154 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.803      |
# |    explained_variance   | 0.599       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0309     |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.00347    |
# |    value_loss           | 0.000718    |
# -----------------------------------------
# ...
# |    n_updates            | 790         |
# |    policy_gradient_loss | -0.00866    |
# |    value_loss           | 0.000301    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 815        |
# |    ep_rew_mean          | 0.416      |
# | time/                   |            |
# |    fps                  | 352        |
# |    iterations           | 81         |
# |    time_elapsed         | 470        |
# |    total_timesteps      | 165888     |
# | train/                  |            |
# |    approx_kl            | 0.01195507 |
# |    clip_fraction        | 0.079      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.549     |
# |    explained_variance   | -4.46      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0238    |
# |    n_updates            | 800        |
# |    policy_gradient_loss | -0.0172    |
# |    value_loss           | 7.42e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 828         |
# |    ep_rew_mean          | 0.395       |
# | time/                   |             |
# |    fps                  | 352         |
# |    iterations           | 82          |
# |    time_elapsed         | 476         |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.008711002 |
# |    clip_fraction        | 0.0955      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.593      |
# |    explained_variance   | 0.0199      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00998    |
# |    n_updates            | 810         |
# |    policy_gradient_loss | -0.00425    |
# |    value_loss           | 0.00297     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 828         |
# |    ep_rew_mean          | 0.398       |
# | time/                   |             |
# |    fps                  | 353         |
# |    iterations           | 83          |
# |    time_elapsed         | 481         |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.022417547 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.683      |
# |    explained_variance   | -0.957      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0166     |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.00969    |
# |    value_loss           | 0.000249    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 846         |
# |    ep_rew_mean          | 0.373       |
# | time/                   |             |
# |    fps                  | 353         |
# |    iterations           | 84          |
# |    time_elapsed         | 486         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.017087108 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.573      |
# |    explained_variance   | -0.092      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0298     |
# |    n_updates            | 830         |
# |    policy_gradient_loss | -0.0122     |
# |    value_loss           | 0.000726    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 837         |
# |    ep_rew_mean          | 0.386       |
# | time/                   |             |
# |    fps                  | 353         |
# |    iterations           | 85          |
# |    time_elapsed         | 492         |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.027512386 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.968      |
# |    explained_variance   | -0.238      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0464     |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.0166     |
# |    value_loss           | 0.000297    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 837         |
# |    ep_rew_mean          | 0.383       |
# | time/                   |             |
# |    fps                  | 353         |
# |    iterations           | 86          |
# |    time_elapsed         | 497         |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.011295067 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.937      |
# |    explained_variance   | 0.308       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0265     |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.00897    |
# |    value_loss           | 0.00177     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 840         |
# |    ep_rew_mean          | 0.376       |
# | time/                   |             |
# |    fps                  | 353         |
# |    iterations           | 87          |
# |    time_elapsed         | 503         |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.016234677 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.85       |
# |    explained_variance   | 0.103       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0265     |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.0145     |
# |    value_loss           | 0.00177     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 849         |
# |    ep_rew_mean          | 0.363       |
# | time/                   |             |
# |    fps                  | 354         |
# |    iterations           | 88          |
# |    time_elapsed         | 509         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.020469502 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.987      |
# |    explained_variance   | 0.613       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0458     |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.0171     |
# |    value_loss           | 0.000306    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 849        |
# |    ep_rew_mean          | 0.364      |
# | time/                   |            |
# |    fps                  | 354        |
# |    iterations           | 89         |
# |    time_elapsed         | 514        |
# |    total_timesteps      | 182272     |
# | train/                  |            |
# |    approx_kl            | 0.01738007 |
# |    clip_fraction        | 0.141      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.746     |
# |    explained_variance   | -0.838     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0408    |
# |    n_updates            | 880        |
# |    policy_gradient_loss | -0.0138    |
# |    value_loss           | 0.000107   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 851         |
# |    ep_rew_mean          | 0.361       |
# | time/                   |             |
# |    fps                  | 353         |
# |    iterations           | 90          |
# |    time_elapsed         | 520         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.013248097 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.714      |
# |    explained_variance   | -0.819      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0468     |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.0229     |
# |    value_loss           | 0.000288    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 851          |
# |    ep_rew_mean          | 0.365        |
# | time/                   |              |
# |    fps                  | 353          |
# |    iterations           | 91           |
# |    time_elapsed         | 526          |
# |    total_timesteps      | 186368       |
# | train/                  |              |
# |    approx_kl            | 0.0111607835 |
# |    clip_fraction        | 0.167        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.788       |
# |    explained_variance   | -0.0264      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00991     |
# |    n_updates            | 900          |
# |    policy_gradient_loss | -0.0104      |
# |    value_loss           | 0.0024       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 856         |
# |    ep_rew_mean          | 0.359       |
# | time/                   |             |
# |    fps                  | 354         |
# |    iterations           | 92          |
# |    time_elapsed         | 531         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.008730872 |
# |    clip_fraction        | 0.0851      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.752      |
# |    explained_variance   | -0.249      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0228     |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 0.00233     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 850         |
# |    ep_rew_mean          | 0.371       |
# | time/                   |             |
# |    fps                  | 354         |
# |    iterations           | 93          |
# |    time_elapsed         | 538         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.013129132 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.926      |
# |    explained_variance   | 0.35        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0175     |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.01       |
# |    value_loss           | 0.000195    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 850         |
# |    ep_rew_mean          | 0.374       |
# | time/                   |             |
# |    fps                  | 354         |
# |    iterations           | 94          |
# |    time_elapsed         | 543         |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.011213085 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.442       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0336     |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 0.00157     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 859       |
# |    ep_rew_mean          | 0.36      |
# | time/                   |           |
# |    fps                  | 354       |
# |    iterations           | 95        |
# |    time_elapsed         | 549       |
# |    total_timesteps      | 194560    |
# | train/                  |           |
# |    approx_kl            | 0.0196301 |
# |    clip_fraction        | 0.136     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.963    |
# |    explained_variance   | 0.614     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0321   |
# |    n_updates            | 940       |
# |    policy_gradient_loss | -0.0119   |
# |    value_loss           | 0.0032    |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 851         |
# |    ep_rew_mean          | 0.371       |
# | time/                   |             |
# |    fps                  | 354         |
# |    iterations           | 96          |
# |    time_elapsed         | 555         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.014873969 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.838      |
# |    explained_variance   | 0.0343      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00814    |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.00803    |
# |    value_loss           | 0.00264     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 851         |
# |    ep_rew_mean          | 0.37        |
# | time/                   |             |
# |    fps                  | 353         |
# |    iterations           | 97          |
# |    time_elapsed         | 562         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.032692283 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.888      |
# |    explained_variance   | 0.553       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0352     |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0143     |
# |    value_loss           | 0.00212     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 851         |
# |    ep_rew_mean          | 0.366       |
# | time/                   |             |
# |    fps                  | 353         |
# |    iterations           | 98          |
# |    time_elapsed         | 568         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.016352702 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.856      |
# |    explained_variance   | -0.381      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0165     |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 0.000352    |
# -----------------------------------------

# %%
env = CustomDoorKey(size=12, intermediate_reward=True, randomize_goal=True, render_mode = "rgb")
default_env = ImgObsWrapper(env)

policy_kwargs = dict(
    features_extractor_class=CNNFeaturesExtractor,
    features_extractor_kwargs=dict(features_dim=128, regularization = False),
)

# Load the trained model, ensure to provide the correct path
model = PPO.load("model_5x5s", env=default_env)

max_reward = 0.9
callback = CustomRewardCallback(check_freq=1000, reward_threshold=max_reward)

model.learn(total_timesteps=int(2e5), callback=callback)
model.save("model_5x5_transfer_12x12")
plt.savefig('5x5_transfer_12x12.png')

env.close()
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 0.167    |
# | time/              |          |
# |    fps             | 494      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 0.0835      |
# | time/                   |             |
# |    fps                  | 459         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015561059 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | -0.841      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0423     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0134     |
# |    value_loss           | 0.00222     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 0.145       |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 3           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008837769 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.81       |
# |    explained_variance   | -0.0716     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0437     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 0.000642    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 0.189      |
# | time/                   |            |
# |    fps                  | 450        |
# |    iterations           | 4          |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01146424 |
# |    clip_fraction        | 0.155      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.73      |
# |    explained_variance   | 0.394      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0141    |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0125    |
# |    value_loss           | 0.00211    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 0.153        |
# | time/                   |              |
# |    fps                  | 447          |
# |    iterations           | 5            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0107647395 |
# |    clip_fraction        | 0.123        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.74        |
# |    explained_variance   | 0.514        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0101      |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00894     |
# |    value_loss           | 0.00046      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 0.168       |
# | time/                   |             |
# |    fps                  | 449         |
# |    iterations           | 6           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011068292 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.75       |
# |    explained_variance   | 0.349       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.024      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 0.000994    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 955         |
# |    ep_rew_mean          | 0.261       |
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 7           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.017928913 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.68       |
# |    explained_variance   | 0.488       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0399     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.017      |
# |    value_loss           | 0.00145     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 963         |
# |    ep_rew_mean          | 0.262       |
# | time/                   |             |
# |    fps                  | 437         |
# |    iterations           | 8           |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.014193907 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | 0.407       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00937     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 0.00257     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 930         |
# |    ep_rew_mean          | 0.308       |
# | time/                   |             |
# |    fps                  | 440         |
# |    iterations           | 9           |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.020925432 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | 0.35        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0275     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00953    |
# |    value_loss           | 0.00127     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 900          |
# |    ep_rew_mean          | 0.376        |
# | time/                   |              |
# |    fps                  | 441          |
# |    iterations           | 10           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0132658575 |
# |    clip_fraction        | 0.172        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.63        |
# |    explained_variance   | 0.369        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00957     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.0113      |
# |    value_loss           | 0.00241      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 909        |
# |    ep_rew_mean          | 0.389      |
# | time/                   |            |
# |    fps                  | 443        |
# |    iterations           | 11         |
# |    time_elapsed         | 50         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.01678936 |
# |    clip_fraction        | 0.169      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.63      |
# |    explained_variance   | 0.491      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0141    |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0124    |
# |    value_loss           | 0.0038     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 916         |
# |    ep_rew_mean          | 0.398       |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 12          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.013472414 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.64       |
# |    explained_variance   | -0.00118    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00118     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 0.00241     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 922         |
# |    ep_rew_mean          | 0.406       |
# | time/                   |             |
# |    fps                  | 447         |
# |    iterations           | 13          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.013977938 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.63       |
# |    explained_variance   | 0.0729      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00405     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00889    |
# |    value_loss           | 0.00108     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 927         |
# |    ep_rew_mean          | 0.399       |
# | time/                   |             |
# |    fps                  | 448         |
# |    iterations           | 14          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.016158214 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.51       |
# |    explained_variance   | 0.11        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0303     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00818    |
# |    value_loss           | 0.00149     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 914         |
# |    ep_rew_mean          | 0.427       |
# | time/                   |             |
# |    fps                  | 446         |
# |    iterations           | 15          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.014281714 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | 0.148       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0353     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 0.000643    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 919         |
# |    ep_rew_mean          | 0.428       |
# | time/                   |             |
# |    fps                  | 446         |
# |    iterations           | 16          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.019073399 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.51       |
# |    explained_variance   | 0.169       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0273      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 0.00294     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 921         |
# |    ep_rew_mean          | 0.438       |
# | time/                   |             |
# |    fps                  | 446         |
# |    iterations           | 17          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.020630296 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.0378      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0241     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.012      |
# |    value_loss           | 0.00171     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 921         |
# |    ep_rew_mean          | 0.432       |
# | time/                   |             |
# |    fps                  | 446         |
# |    iterations           | 18          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.014516344 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.108       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.02       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 0.000812    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 924         |
# |    ep_rew_mean          | 0.438       |
# | time/                   |             |
# |    fps                  | 442         |
# |    iterations           | 19          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.017819222 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.51       |
# |    explained_variance   | 0.357       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00477    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 0.000905    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 918         |
# |    ep_rew_mean          | 0.453       |
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 20          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.016087424 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.175       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0131     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00615    |
# |    value_loss           | 0.00124     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 900         |
# |    ep_rew_mean          | 0.479       |
# | time/                   |             |
# |    fps                  | 442         |
# |    iterations           | 21          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.015774287 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | 0.293       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0255     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 0.00252     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | 0.483       |
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 22          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.017245155 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.559       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0173     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0132     |
# |    value_loss           | 0.00305     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 896         |
# |    ep_rew_mean          | 0.493       |
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 23          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.017036181 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.28        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0308     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 0.00139     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 881         |
# |    ep_rew_mean          | 0.516       |
# | time/                   |             |
# |    fps                  | 444         |
# |    iterations           | 24          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.017118469 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.628       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0218      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00859    |
# |    value_loss           | 0.00204     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 864         |
# |    ep_rew_mean          | 0.54        |
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 25          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.018819474 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.662       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00154    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 0.00391     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 869         |
# |    ep_rew_mean          | 0.541       |
# | time/                   |             |
# |    fps                  | 444         |
# |    iterations           | 26          |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.019724604 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.57        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0151      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.015      |
# |    value_loss           | 0.00441     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 871         |
# |    ep_rew_mean          | 0.545       |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 27          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.018565547 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.491       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0208     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00936    |
# |    value_loss           | 0.00184     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 863         |
# |    ep_rew_mean          | 0.556       |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 28          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.013596514 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.262       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0328     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00619    |
# |    value_loss           | 0.00263     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 863         |
# |    ep_rew_mean          | 0.558       |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 29          |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.023014408 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.616       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00549    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00757    |
# |    value_loss           | 0.00229     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 867         |
# |    ep_rew_mean          | 0.552       |
# | time/                   |             |
# |    fps                  | 446         |
# |    iterations           | 30          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.027089667 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.749       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0457     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00648    |
# |    value_loss           | 0.00137     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 866         |
# |    ep_rew_mean          | 0.558       |
# | time/                   |             |
# |    fps                  | 446         |
# |    iterations           | 31          |
# |    time_elapsed         | 142         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.013044763 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.218       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00526    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00576    |
# |    value_loss           | 0.00144     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 866         |
# |    ep_rew_mean          | 0.562       |
# | time/                   |             |
# |    fps                  | 446         |
# |    iterations           | 32          |
# |    time_elapsed         | 146         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.013298752 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.442       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0205     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00761    |
# |    value_loss           | 0.0024      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 867         |
# |    ep_rew_mean          | 0.565       |
# | time/                   |             |
# |    fps                  | 447         |
# |    iterations           | 33          |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.017182603 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.529       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0481     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 0.00321     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 861         |
# |    ep_rew_mean          | 0.574       |
# | time/                   |             |
# |    fps                  | 447         |
# |    iterations           | 34          |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.016201986 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.298       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0168     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00498    |
# |    value_loss           | 0.00196     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 853        |
# |    ep_rew_mean          | 0.582      |
# | time/                   |            |
# |    fps                  | 447        |
# |    iterations           | 35         |
# |    time_elapsed         | 160        |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.01748873 |
# |    clip_fraction        | 0.169      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.07      |
# |    explained_variance   | 0.409      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0184    |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.00685   |
# |    value_loss           | 0.00329    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 847        |
# |    ep_rew_mean          | 0.593      |
# | time/                   |            |
# |    fps                  | 447        |
# |    iterations           | 36         |
# |    time_elapsed         | 164        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.02436431 |
# |    clip_fraction        | 0.177      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.05      |
# |    explained_variance   | 0.367      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.065      |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.0132    |
# |    value_loss           | 0.00467    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 814         |
# |    ep_rew_mean          | 0.636       |
# | time/                   |             |
# |    fps                  | 446         |
# |    iterations           | 37          |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.015508001 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.736       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0117     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00342    |
# |    value_loss           | 0.00282     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 775         |
# |    ep_rew_mean          | 0.684       |
# | time/                   |             |
# |    fps                  | 444         |
# |    iterations           | 38          |
# |    time_elapsed         | 175         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.016222661 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.648       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0325     |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0178     |
# |    value_loss           | 0.00941     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 767         |
# |    ep_rew_mean          | 0.705       |
# | time/                   |             |
# |    fps                  | 444         |
# |    iterations           | 39          |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.016119048 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.665       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0441     |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00853    |
# |    value_loss           | 0.0107      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 742         |
# |    ep_rew_mean          | 0.744       |
# | time/                   |             |
# |    fps                  | 444         |
# |    iterations           | 40          |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.020680387 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.498       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00922    |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00758    |
# |    value_loss           | 0.00409     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 742         |
# |    ep_rew_mean          | 0.755       |
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 41          |
# |    time_elapsed         | 189         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.016785257 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.548       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0119     |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00615    |
# |    value_loss           | 0.00821     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 725         |
# |    ep_rew_mean          | 0.786       |
# | time/                   |             |
# |    fps                  | 441         |
# |    iterations           | 42          |
# |    time_elapsed         | 194         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.015938293 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.994      |
# |    explained_variance   | 0.308       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0051     |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.00385    |
# |    value_loss           | 0.00181     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 712         |
# |    ep_rew_mean          | 0.806       |
# | time/                   |             |
# |    fps                  | 440         |
# |    iterations           | 43          |
# |    time_elapsed         | 199         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.014164031 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.488       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0213     |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.00315    |
# |    value_loss           | 0.00932     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 705         |
# |    ep_rew_mean          | 0.818       |
# | time/                   |             |
# |    fps                  | 439         |
# |    iterations           | 44          |
# |    time_elapsed         | 204         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.015101797 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.29        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0346     |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.0145     |
# |    value_loss           | 0.00635     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 683         |
# |    ep_rew_mean          | 0.843       |
# | time/                   |             |
# |    fps                  | 438         |
# |    iterations           | 45          |
# |    time_elapsed         | 210         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.022803035 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.14        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0181      |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.01       |
# |    value_loss           | 0.0022      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 663        |
# |    ep_rew_mean          | 0.87       |
# | time/                   |            |
# |    fps                  | 438        |
# |    iterations           | 46         |
# |    time_elapsed         | 214        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.01772796 |
# |    clip_fraction        | 0.172      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.995     |
# |    explained_variance   | 0.374      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0188    |
# |    n_updates            | 580        |
# |    policy_gradient_loss | -0.0108    |
# |    value_loss           | 0.00745    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 658         |
# |    ep_rew_mean          | 0.88        |
# | time/                   |             |
# |    fps                  | 438         |
# |    iterations           | 47          |
# |    time_elapsed         | 219         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.024166122 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.55        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0132     |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.00561    |
# |    value_loss           | 0.00689     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 650         |
# |    ep_rew_mean          | 0.882       |
# | time/                   |             |
# |    fps                  | 438         |
# |    iterations           | 48          |
# |    time_elapsed         | 224         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.023131542 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | -0.445      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0469     |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.00992    |
# |    value_loss           | 0.00264     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 620         |
# |    ep_rew_mean          | 0.921       |
# | time/                   |             |
# |    fps                  | 437         |
# |    iterations           | 49          |
# |    time_elapsed         | 229         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.018809298 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.469       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0252     |
# |    n_updates            | 610         |
# |    policy_gradient_loss | -0.00549    |
# |    value_loss           | 0.00303     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 607        |
# |    ep_rew_mean          | 0.934      |
# | time/                   |            |
# |    fps                  | 437        |
# |    iterations           | 50         |
# |    time_elapsed         | 233        |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.01646832 |
# |    clip_fraction        | 0.15       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.898     |
# |    explained_variance   | 0.432      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.001      |
# |    n_updates            | 620        |
# |    policy_gradient_loss | -0.00581   |
# |    value_loss           | 0.00826    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 614         |
# |    ep_rew_mean          | 0.925       |
# | time/                   |             |
# |    fps                  | 438         |
# |    iterations           | 51          |
# |    time_elapsed         | 238         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.030692846 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.41        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00545    |
# |    n_updates            | 630         |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 0.00556     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 603         |
# |    ep_rew_mean          | 0.939       |
# | time/                   |             |
# |    fps                  | 438         |
# |    iterations           | 52          |
# |    time_elapsed         | 243         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.009725435 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.792      |
# |    explained_variance   | -0.249      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0167     |
# |    n_updates            | 640         |
# |    policy_gradient_loss | -0.000474   |
# |    value_loss           | 0.0021      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 605         |
# |    ep_rew_mean          | 0.941       |
# | time/                   |             |
# |    fps                  | 438         |
# |    iterations           | 53          |
# |    time_elapsed         | 247         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.018926382 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.918      |
# |    explained_variance   | 0.357       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0232     |
# |    n_updates            | 650         |
# |    policy_gradient_loss | -0.00535    |
# |    value_loss           | 0.0052      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 605         |
# |    ep_rew_mean          | 0.943       |
# | time/                   |             |
# |    fps                  | 438         |
# |    iterations           | 54          |
# |    time_elapsed         | 252         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.015224485 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.815      |
# |    explained_variance   | 0.436       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0382     |
# |    n_updates            | 660         |
# |    policy_gradient_loss | -0.00675    |
# |    value_loss           | 0.00221     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 587         |
# |    ep_rew_mean          | 0.963       |
# | time/                   |             |
# |    fps                  | 438         |
# |    iterations           | 55          |
# |    time_elapsed         | 257         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.027894907 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.781      |
# |    explained_variance   | 0.382       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0302     |
# |    n_updates            | 670         |
# |    policy_gradient_loss | -0.00242    |
# |    value_loss           | 0.00524     |
# ...
# |    entropy_loss         | -0.429      |
# |    explained_variance   | 0.19        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0192     |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.00893    |
# |    value_loss           | 0.02        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 309         |
# |    ep_rew_mean          | 1.27        |
# | time/                   |             |
# |    fps                  | 407         |
# |    iterations           | 81          |
# |    time_elapsed         | 406         |
# |    total_timesteps      | 165888      |
# | train/                  |             |
# |    approx_kl            | 0.035004724 |
# |    clip_fraction        | 0.323       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.293      |
# |    explained_variance   | 0.522       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0644     |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.0332     |
# |    value_loss           | 0.00672     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 310         |
# |    ep_rew_mean          | 1.27        |
# | time/                   |             |
# |    fps                  | 408         |
# |    iterations           | 82          |
# |    time_elapsed         | 411         |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.048261568 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.207      |
# |    explained_variance   | 0.307       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0385     |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.00664    |
# |    value_loss           | 0.0121      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 316        |
# |    ep_rew_mean          | 1.26       |
# | time/                   |            |
# |    fps                  | 408        |
# |    iterations           | 83         |
# |    time_elapsed         | 415        |
# |    total_timesteps      | 169984     |
# | train/                  |            |
# |    approx_kl            | 0.07225048 |
# |    clip_fraction        | 0.221      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.372     |
# |    explained_variance   | 0.0839     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0512    |
# |    n_updates            | 950        |
# |    policy_gradient_loss | -0.00463   |
# |    value_loss           | 0.00668    |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 321      |
# |    ep_rew_mean          | 1.25     |
# | time/                   |          |
# |    fps                  | 408      |
# |    iterations           | 84       |
# |    time_elapsed         | 420      |
# |    total_timesteps      | 172032   |
# | train/                  |          |
# |    approx_kl            | 0.069582 |
# |    clip_fraction        | 0.103    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.198   |
# |    explained_variance   | 0.03     |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.015   |
# |    n_updates            | 960      |
# |    policy_gradient_loss | -0.0026  |
# |    value_loss           | 0.00284  |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 318       |
# |    ep_rew_mean          | 1.26      |
# | time/                   |           |
# |    fps                  | 408       |
# |    iterations           | 85        |
# |    time_elapsed         | 426       |
# |    total_timesteps      | 174080    |
# | train/                  |           |
# |    approx_kl            | 0.0468604 |
# |    clip_fraction        | 0.184     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.509    |
# |    explained_variance   | -0.0599   |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.000527 |
# |    n_updates            | 970       |
# |    policy_gradient_loss | -0.00848  |
# |    value_loss           | 0.00732   |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 306        |
# |    ep_rew_mean          | 1.27       |
# | time/                   |            |
# |    fps                  | 406        |
# |    iterations           | 86         |
# |    time_elapsed         | 432        |
# |    total_timesteps      | 176128     |
# | train/                  |            |
# |    approx_kl            | 0.03578251 |
# |    clip_fraction        | 0.171      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.527     |
# |    explained_variance   | 0.317      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.022      |
# |    n_updates            | 980        |
# |    policy_gradient_loss | -0.00251   |
# |    value_loss           | 0.00694    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 294         |
# |    ep_rew_mean          | 1.28        |
# | time/                   |             |
# |    fps                  | 405         |
# |    iterations           | 87          |
# |    time_elapsed         | 439         |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.052680712 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.482      |
# |    explained_variance   | -0.0688     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0729     |
# |    n_updates            | 990         |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 0.0139      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 308         |
# |    ep_rew_mean          | 1.26        |
# | time/                   |             |
# |    fps                  | 405         |
# |    iterations           | 88          |
# |    time_elapsed         | 444         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.017094135 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.336      |
# |    explained_variance   | 0.292       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0158      |
# |    n_updates            | 1000        |
# |    policy_gradient_loss | -0.0044     |
# |    value_loss           | 0.0122      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 299         |
# |    ep_rew_mean          | 1.27        |
# | time/                   |             |
# |    fps                  | 404         |
# |    iterations           | 89          |
# |    time_elapsed         | 450         |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.027023703 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.508      |
# |    explained_variance   | 0.317       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0267     |
# |    n_updates            | 1010        |
# |    policy_gradient_loss | 0.00307     |
# |    value_loss           | 0.0062      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 292         |
# |    ep_rew_mean          | 1.28        |
# | time/                   |             |
# |    fps                  | 402         |
# |    iterations           | 90          |
# |    time_elapsed         | 457         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.014565139 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.409      |
# |    explained_variance   | 0.36        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0014      |
# |    n_updates            | 1020        |
# |    policy_gradient_loss | -0.00395    |
# |    value_loss           | 0.0165      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 280         |
# |    ep_rew_mean          | 1.3         |
# | time/                   |             |
# |    fps                  | 402         |
# |    iterations           | 91          |
# |    time_elapsed         | 462         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.043430973 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.408      |
# |    explained_variance   | 0.428       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00915     |
# |    n_updates            | 1030        |
# |    policy_gradient_loss | -0.00798    |
# |    value_loss           | 0.0213      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 284         |
# |    ep_rew_mean          | 1.29        |
# | time/                   |             |
# |    fps                  | 402         |
# |    iterations           | 92          |
# |    time_elapsed         | 467         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.032149073 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.411      |
# |    explained_variance   | 0.184       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00187     |
# |    n_updates            | 1040        |
# |    policy_gradient_loss | -0.00683    |
# |    value_loss           | 0.00657     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 290         |
# |    ep_rew_mean          | 1.28        |
# | time/                   |             |
# |    fps                  | 402         |
# |    iterations           | 93          |
# |    time_elapsed         | 473         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.030868514 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.246      |
# |    explained_variance   | 0.389       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0121     |
# |    n_updates            | 1050        |
# |    policy_gradient_loss | -0.00767    |
# |    value_loss           | 0.00559     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 246        |
# |    ep_rew_mean          | 1.33       |
# | time/                   |            |
# |    fps                  | 400        |
# |    iterations           | 94         |
# |    time_elapsed         | 481        |
# |    total_timesteps      | 192512     |
# | train/                  |            |
# |    approx_kl            | 0.03606693 |
# |    clip_fraction        | 0.0966     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.355     |
# |    explained_variance   | 0.481      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0185     |
# |    n_updates            | 1060       |
# |    policy_gradient_loss | -0.00549   |
# |    value_loss           | 0.0064     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 230        |
# |    ep_rew_mean          | 1.35       |
# | time/                   |            |
# |    fps                  | 400        |
# |    iterations           | 95         |
# |    time_elapsed         | 486        |
# |    total_timesteps      | 194560     |
# | train/                  |            |
# |    approx_kl            | 0.04593406 |
# |    clip_fraction        | 0.156      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.31      |
# |    explained_variance   | 0.537      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00398   |
# |    n_updates            | 1070       |
# |    policy_gradient_loss | -0.0126    |
# |    value_loss           | 0.0213     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 231        |
# |    ep_rew_mean          | 1.35       |
# | time/                   |            |
# |    fps                  | 400        |
# |    iterations           | 96         |
# |    time_elapsed         | 491        |
# |    total_timesteps      | 196608     |
# | train/                  |            |
# |    approx_kl            | 0.01805882 |
# |    clip_fraction        | 0.112      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.486     |
# |    explained_variance   | 0.841      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0348     |
# |    n_updates            | 1080       |
# |    policy_gradient_loss | -0.00524   |
# |    value_loss           | 0.0049     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 246         |
# |    ep_rew_mean          | 1.33        |
# | time/                   |             |
# |    fps                  | 400         |
# |    iterations           | 97          |
# |    time_elapsed         | 496         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.055761248 |
# |    clip_fraction        | 0.339       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.544      |
# |    explained_variance   | 0.817       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0185     |
# |    n_updates            | 1090        |
# |    policy_gradient_loss | -0.0198     |
# |    value_loss           | 0.00514     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 246        |
# |    ep_rew_mean          | 1.33       |
# | time/                   |            |
# |    fps                  | 399        |
# |    iterations           | 98         |
# |    time_elapsed         | 502        |
# |    total_timesteps      | 200704     |
# | train/                  |            |
# |    approx_kl            | 0.04286141 |
# |    clip_fraction        | 0.179      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.478     |
# |    explained_variance   | 0.299      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0138     |
# |    n_updates            | 1100       |
# |    policy_gradient_loss | -0.0098    |
# |    value_loss           | 0.00658    |
# ----------------------------------------
